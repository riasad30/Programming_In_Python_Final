# %% [markdown]
# <a href="https://colab.research.google.com/github/riasad30/Programming_In_Python_Final/blob/main/python_final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Final Project

# %% [markdown]
# Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Dataset Added

# %%
url = "https://raw.githubusercontent.com/riasad30/Programming_In_Python_Final/main/anime.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    anime_id                         title  score  rank  popularity  members  \
# 0     28977                      Gintama°   9.05     8         347   680037
# 1     57555  Chainsaw Man Movie: Reze-hen   9.18     2         962   282129
# 2     11061        Hunter x Hunter (2011)   9.03     9           8  3107455
# 3     52991             Sousou no Frieren   9.29     1         121  1269074
# 4      9969                      Gintama'   9.02    11         406   601940
#
#                                             synopsis  start_date    end_date  \
# 0  Gintoki, Shinpachi, and Kagura return as the f...  2015-01-01  2016-01-01
# 1                           Sequel to Chainsaw Man .  2025-01-01  2025-01-01
# 2  Hunters devote themselves to accomplishing haz...  2011-01-01  2014-01-01
# 3  During their decade-long quest to defeat the D...  2023-01-01  2024-01-01
# 4  After a one-year hiatus, Shinpachi Shimura ret...  2011-01-01  2012-01-01
#
#     type  episodes                                          image_url
# 0     TV      51.0  https://cdn.myanimelist.net/images/anime/3/720...
# 1  Movie       1.0  https://cdn.myanimelist.net/images/anime/1763/...
# 2     TV     148.0  https://cdn.myanimelist.net/images/anime/1337/...
# 3     TV      28.0  https://cdn.myanimelist.net/images/anime/1015/...
# 4     TV      51.0  https://cdn.myanimelist.net/images/anime/4/503...

# %% [markdown]
# Show number of row and columns

# %%
print("Dataset shape (rows, columns):", df.shape)
# Out:
# Dataset shape (rows, columns): (10000, 12)

# %% [markdown]
# Show all columns name

# %%
print("Dataset columns:", df.columns.tolist())
# Out:
# Dataset columns: ['anime_id', 'title', 'score', 'rank', 'popularity', 'members', 'synopsis', 'start_date', 'end_date', 'type', 'episodes', 'image_url']

# %% [markdown]
# Show all columns name with datatype

# %%
print("Data types  :\n", df.dtypes)
# Out:
# Data types  :
#  anime_id        int64
# title          object
# score         float64
# rank            int64
# popularity      int64
# members         int64
# synopsis       object
# start_date     object
# end_date       object
# type           object
# episodes      float64
# image_url      object
# dtype: object

# %% [markdown]
# Show Dataset info

# %%
print("Dataset info:")
df.info()
# Out:
# Dataset info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   anime_id    10000 non-null  int64
#  1   title       10000 non-null  object
#  2   score       10000 non-null  float64
#  3   rank        10000 non-null  int64
#  4   popularity  10000 non-null  int64
#  5   members     10000 non-null  int64
#  6   synopsis    9998 non-null   object
#  7   start_date  9998 non-null   object
#  8   end_date    9916 non-null   object
#  9   type        10000 non-null  object
#  10  episodes    9952 non-null   float64
#  11  image_url   10000 non-null  object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 937.6+ KB

# %% [markdown]
# Show Statistical Summary

# %%
print("Summary statistics:")
print(df.describe())
# Out:
# Summary statistics:
#            anime_id         score          rank    popularity       members  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  1.000000e+04
# mean   24129.128000      6.980589   5000.494000   6490.903700  1.075309e+05
# std    19948.188153      0.619406   2886.898727   4646.309341  2.733514e+05
# min        1.000000      6.050000      1.000000      1.000000  2.260000e+02
# 25%     4055.500000      6.470000   2500.750000   2591.750000  4.270250e+03
# 50%    21406.000000      6.900000   5000.500000   5564.500000  1.817900e+04
# 75%    40028.750000      7.390000   7500.250000   9824.250000  8.469275e+04
# max    62863.000000      9.290000  10000.000000  22184.000000  4.262220e+06
#
#           episodes
# count  9952.000000
# mean     15.702271
# std      41.865696
# min       1.000000
# 25%       1.000000
# 50%      11.000000
# 75%      13.000000
# max    1787.000000

# %% [markdown]
# Show number pf Missing value of each column

# %%
print("Missing values in each column:")
print(df.isnull().sum())
# Out:
# Missing values in each column:
# anime_id       0
# title          0
# score          0
# rank           0
# popularity     0
# members        0
# synopsis       2
# start_date     2
# end_date      84
# type           0
# episodes      48
# image_url      0
# dtype: int64

# %% [markdown]
# Handle missing value and check again

# %%
df = df.dropna(subset=['synopsis', 'start_date'])

df['episodes'] = df['episodes'].fillna(df['episodes'].median())

df['end_date'] = df['end_date'].fillna("Unknown")


print("Missing values after:")
print(df.isnull().sum())
# Out:
# Missing values after:
# anime_id      0
# title         0
# score         0
# rank          0
# popularity    0
# members       0
# synopsis      0
# start_date    0
# end_date      0
# type          0
# episodes      0
# image_url     0
# dtype: int64

# %% [markdown]
# See number of duplicate rows

# %%
print("Duplicate rows before:", df.duplicated().sum())
# Out:
# Duplicate rows before: 1

# %% [markdown]
# Drop duplicate rows

# %%
df = df.drop_duplicates()
print("Duplicate rows after:", df.duplicated().sum())
# Out:
# Duplicate rows after: 0

# %%
print("Data types before:")
print(df.dtypes)
# Out:
# Data types before:
# anime_id        int64
# title          object
# score         float64
# rank            int64
# popularity      int64
# members         int64
# synopsis       object
# start_date     object
# end_date       object
# type           object
# episodes      float64
# image_url      object
# dtype: object

# %% [markdown]
# Change Datatype

# %%
df['start_date'] = pd.to_datetime(df['start_date'], errors='coerce')
df['end_date'] = pd.to_datetime(df['end_date'], errors='coerce')


print("Data types after:")
print(df.dtypes)
# Out:
# Data types after:
# anime_id               int64
# title                 object
# score                float64
# rank                   int64
# popularity             int64
# members                int64
# synopsis              object
# start_date    datetime64[ns]
# end_date      datetime64[ns]
# type                  object
# episodes             float64
# image_url             object
# dtype: object

# %% [markdown]
# Create popularity a new Column group (based on members)
# Normalize score (0 to 1 scale)

# %%
df['start_date'] = pd.to_datetime(df['start_date'], errors='coerce')
df['year'] = df['start_date'].dt.year


df['popularity_group'] = pd.cut(
    df['members'],
    bins=[0, 10000, 100000, df['members'].max()],
    labels=['Low', 'Medium', 'High']
)


df['score_normalized'] = (
    (df['score'] - df['score'].min()) /
    (df['score'].max() - df['score'].min())
)


print(df[['year', 'popularity_group', 'score_normalized']].head())
# Out:
#    year popularity_group  score_normalized
# 0  2015             High          0.925926
# 1  2025             High          0.966049
# 2  2011             High          0.919753
# 3  2023             High          1.000000
# 4  2011             High          0.916667

# %% [markdown]
# Average score by type

# %%
group_type = df.groupby('type')['score'].mean()
print("Average score by type  :\n", group_type)
# Out:
# Average score by type  :
#  type
# Movie         7.067724
# ONA           6.876420
# OVA           6.880923
# Special       6.788544
# TV            7.069319
# TV Special    6.788545
# Name: score, dtype: float64

# %% [markdown]
# Comparison 1: Type vs Score

# %%
print("Average score by type:")
print(df.groupby('type')['score'].mean())
# Out:
# Average score by type:
# type
# Movie         7.067724
# ONA           6.876420
# OVA           6.880923
# Special       6.788544
# TV            7.069319
# TV Special    6.788545
# Name: score, dtype: float64

# %% [markdown]
# Comparison 2: Popularity Group vs Members

# %%
print(df.groupby(df['popularity_group'].astype(str))['members'].mean())
# Out:
# popularity_group
# High      406184.300000
# Low         3785.917209
# Medium     38048.073321
# Name: members, dtype: float64

# %% [markdown]
# Relationship Analysis- Score , Members
#
# Research Question 2
#
# Is there a relationship between an anime’s rating (score) and its popularity (number of members)?

# %%
corr = df[['score', 'members']].corr()
print("Correlation:\n", corr)


plt.scatter(df['score'], df['members'])
plt.xlabel("Score")
plt.ylabel("Members")
plt.title("Score vs Members")
plt.show()
# Out:
# Correlation:
#              score   members
# score    1.000000  0.436472
# members  0.436472  1.000000

# %% [markdown]
# Detect outliers using IQR

# %%
Q1 = df['score'].quantile(0.25)
Q3 = df['score'].quantile(0.75)
IQR = Q3 - Q1

outliers = df[(df['score'] < Q1 - 1.5*IQR) | (df['score'] > Q3 + 1.5*IQR)]

print("Outliers in score:")
print(outliers[['title', 'score']])
# Out:
# Outliers in score:
#                                                 title  score
# 0                                            Gintama°   9.05
# 1                        Chainsaw Man Movie: Reze-hen   9.18
# 2                              Hunter x Hunter (2011)   9.03
# 3                                   Sousou no Frieren   9.29
# 4                                            Gintama'   9.02
# 5                                 Gintama': Enchousen   9.02
# 6                                  Gintama: The Final   9.05
# 7                  Shingeki no Kyojin Season 3 Part 2   9.05
# 8                                            Gintama.   8.98
# 9                           Bleach: Sennen Kessen-hen   8.99
# 10                   Fullmetal Alchemist: Brotherhood   9.10
# 11         Kaguya-sama wa Kokurasetai: Ultra Romantic   8.96
# 12                                            Gintama   8.93
# 13                               Clannad: After Story   8.93
# 14                  Kusuriya no Hitorigoto 2nd Season   8.91
# 15                 Code Geass: Hangyaku no Lelouch R2   8.91
# 16                               Ginga Eiyuu Densetsu   9.02
# 17  Gintama Movie 2: Kanketsu-hen - Yorozuya yo Ei...   8.89
# 18                                     Koe no Katachi   8.93
# 19                                 Kingdom 6th Season   9.06
# 20                                            Monster   8.89
# 21                Boku no Hero Academia: Final Season   8.88
# 22                             Kusuriya no Hitorigoto   8.86
# 23                               One Piece Fan Letter   9.02
# 24                         3-gatsu no Lion 2nd Season   8.90
# 25                                 Kingdom 3rd Season   8.84
# 26                            Violet Evergarden Movie   8.84
# 27  Shingeki no Kyojin: The Final Season - Kankets...   8.86
# 28                                        Steins;Gate   9.07
# 29                           Fruits Basket: The Final   8.94
# 30    Gintama. Shirogane no Tamashii-hen - Kouhan-sen   8.88
# 31                         Owarimonogatari 2nd Season   8.86
# 32                   Kizumonogatari III: Reiketsu-hen   8.78
# 33  Shingeki no Kyojin Movie: Kanketsu-hen - The L...   8.83
# 34                                     Kimi no Na wa.   8.83
# 35                                  Takopii no Genzai   8.79
# 36                                  Mob Psycho 100 II   8.78
# 37                                     Hajime no Ippo   8.78
# 42               Shingeki no Kyojin: The Final Season   8.78
# 45                 Gintama. Shirogane no Tamashii-hen   8.81
# 46                              Vinland Saga Season 2   8.82

# %% [markdown]
# Date is converted
#
# Number of anime per year

# %%
df['start_date'] = pd.to_datetime(df['start_date'], errors='coerce')
df['year'] = df['start_date'].dt.year


trend = df.groupby('year').size()

print("Anime released per year:\n", trend)


trend.plot(kind='line')
plt.title("Anime Releases Over Time")
plt.xlabel("Year")
plt.ylabel("Count")
plt.show()
# Out:
# Anime released per year:
#  year
# 1956      1
# 1959      1
# 1960      1
# 1961      3
# 1962      1
#        ...
# 2021    418
# 2022    416
# 2023    473
# 2024    442
# 2025    329
# Length: 68, dtype: int64

# %% [markdown]
# Mean - This is the average rating of all anime
#
# Percentile - 90% of anime have a score less than 7.84
#
# Z-score - how far a value is from the average

# %%
print("Mean score:", np.mean(df['score']))


print("90th percentile of score:", np.percentile(df['score'], 90))


df['z_score'] = (df['score'] - np.mean(df['score'])) / np.std(df['score'])
print("Z-score sample:\n", df[['score', 'z_score']].head())


df['score_norm'] = (df['score'] - np.min(df['score'])) / (np.max(df['score']) - np.min(df['score']))
# Out:
# Mean score: 6.980828414207104
# 90th percentile of score: 7.84
# Z-score sample:
#     score   z_score
# 0   9.05  3.340724
# 1   9.18  3.550612
# 2   9.03  3.308433
# 3   9.29  3.728209
# 4   9.02  3.292288

# %% [markdown]
# Bar Chart (Average Score by Type)
#
# Compares average ratings across anime types
#
# Research Question 1
# Which types of anime (TV, Movie, OVA) have the highest average ratings?

# %%
avg_score = df.groupby('type')['score'].mean()

avg_score.plot(kind='bar')
plt.title("Average Score by Anime Type")
plt.xlabel("Type")
plt.ylabel("Average Score")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Line Chart (Trend Over Time)
#
# Number of anime released each year.
#
# Research Question 3
#
# How has anime production changed over time based on release year?

# %%
df['start_date'] = pd.to_datetime(df['start_date'], errors='coerce')
df['year'] = df['start_date'].dt.year

trend = df.groupby('year').size()

trend.plot(kind='line')
plt.title("Anime Releases Over Time")
plt.xlabel("Year")
plt.ylabel("Number of Anime")
plt.show()

# %% [markdown]
# Histogram-Distribution of ratings.

# %%
df['score'].plot(kind='hist', bins=20)
plt.title("Distribution of Anime Scores")
plt.xlabel("Score")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Scatter Plot - Relationship between rating and popularity.

# %% [markdown]
# Box Plot- It shows the spread and outliers in scores.
#
# It helps detect unusual values.

# %%
df.boxplot(column='score')
plt.title("Box Plot of Scores")
plt.ylabel("Score")
plt.show()

# %% [markdown]
# Average Anime Score Over Years

# %%
df['start_date'] = pd.to_datetime(df['start_date'], errors='coerce')
df['year'] = df['start_date'].dt.year

yearly_score = df.groupby('year')['score'].mean()

plt.figure(figsize=(8,5))
yearly_score.plot(kind='line')

plt.title("Average Anime Score Over Years")
plt.xlabel("Year")
plt.ylabel("Average Score")

plt.show()

# %% [markdown]
# Top 10 Most Popular Anime (by Members)

# %%
top_popular = df.sort_values(by='members', ascending=False).head(10)

plt.figure(figsize=(8,5))
plt.barh(top_popular['title'], top_popular['members'])

plt.title("Top 10 Most Popular Anime")
plt.xlabel("Number of Members")
plt.ylabel("Anime Title")

plt.gca().invert_yaxis()
plt.show()
